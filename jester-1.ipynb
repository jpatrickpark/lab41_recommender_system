# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mn
# %matplotlib inline
plt.rcParams['figure.figsize'] = 12, 12
import warnings
warnings.filterwarnings('ignore')

# %%
raw_data = pd.read_excel("data/jester-data-1.xls", header=None)

# %%
raw_data.describe()
# Out:
#                 0             1             2             3             4    \
# count  24983.000000  24983.000000  24983.000000  24983.000000  24983.000000
# mean      72.467478     34.401435     27.094089     33.263717     36.244936
# std       21.859600     46.707059     44.228006     46.747535     48.812967
# min       36.000000     -9.950000     -9.950000     -9.950000     -9.950000
# 25%       53.000000     -0.150000     -2.180000     -1.145000     -3.350000
# 50%       72.000000      5.050000      3.690000      4.660000      3.450000
# 75%      100.000000     99.000000     99.000000     99.000000     99.000000
# max      100.000000     99.000000     99.000000     99.000000     99.000000
#
#                 5             6             7             8             9    \
# count  24983.000000  24983.000000  24983.000000  24983.000000  24983.000000
# mean       0.427236     19.342119     -0.401803     -0.616110     36.228421
# ...

# %%
df = raw_data.loc[:,1:].replace(99,np.nan)

# %%
mn.matrix(df)

# %%
df.describe()
# Out:
#                 1             2             3             4             5    \
# count  16452.000000  18184.000000  16642.000000  15608.000000  24977.000000
# mean       0.904573      0.208460      0.316574     -1.449114      0.403556
# std        5.171798      5.597327      5.399806      5.234654      5.255700
# min       -9.950000     -9.950000     -9.950000     -9.950000     -9.950000
# 25%             NaN           NaN           NaN           NaN           NaN
# 50%             NaN           NaN           NaN           NaN           NaN
# 75%             NaN           NaN           NaN           NaN           NaN
# max        9.370000      9.370000      9.370000      9.370000      9.370000
#
#                 6             7             8             9             10   \
# count  20431.000000  24976.000000  24981.000000  15752.000000  20324.000000
# mean       1.594447     -0.429662     -0.624085     -0.557031      1.301231
# ...

# %%
# center by subtracting average rating of all entries from each entry
centeredMatrix = df - df.sum().sum() / df.count().sum()

# %%
centeredMatrix.describe()
# Out:
#                 1             2             3             4             5    \
# count  16452.000000  18184.000000  16642.000000  15608.000000  24977.000000
# mean       0.024814     -0.671300     -0.563185     -2.328873     -0.476203
# std        5.171798      5.597327      5.399806      5.234654      5.255700
# min      -10.829759    -10.829759    -10.829759    -10.829759    -10.829759
# 25%             NaN           NaN           NaN           NaN           NaN
# 50%             NaN           NaN           NaN           NaN           NaN
# 75%             NaN           NaN           NaN           NaN           NaN
# max        8.490241      8.490241      8.490241      8.490241      8.490241
#
#                 6             7             8             9             10   \
# count  20431.000000  24976.000000  24981.000000  15752.000000  20324.000000
# mean       0.714688     -1.309422     -1.503844     -1.436790      0.421471
# ...

# %%
# u, s, v = np.linalg.svd(centeredMatrix.T)
# Approximation method needed
